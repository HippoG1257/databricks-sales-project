# %%
from pyspark.sql import functions as F
data=[
    (1,"laptop",2,50000),
    (2,"mobile",3,30000),
    (3,"Tablet",1,20000),
    (4,"laptop",2,50000)
]
columns = ["id","product","quantity","price"]
df = spark.createDataFrame(data,columns)
 
result=df.withColumn('Tax',F.col('amount')*0.10)
display(result)
